# %%
## Right rotate an array by 1 place

# %%
arr = [3,2,3,676,86,0]
l = len(arr)
arr[:] = [arr[l-1]] + arr[0:l-1]
arr
# Out:
# [0, 3, 2, 3, 676, 86]

# %%
arr = [3,2,3,676,86,0]
l = len(arr)
temp = arr[l-1]
for i in range(l-2 , -1,-1):
    arr[i+1] = arr[i]
